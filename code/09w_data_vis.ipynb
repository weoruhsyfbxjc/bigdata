# %% [markdown]
# <a href="https://colab.research.google.com/github/weoruhsyfbxjc/bigdata/blob/main/code/09w_data_vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install koreanize-matplotlib
import koreanize_matplotlib
# %config inlineBackend.figure_format = 'retina'
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 96.5 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (5, 3)

# %%
# !pip show pydataset
# Out:
# WARNING: Package(s) not found: pydataset

# %%
# !pip install pydataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 92.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939415 sha256=5bf4a46dc2b99dcf48e32147ddc29c5557a7f8f7fe11244799f01845e400e530
#   Stored in directory: /root/.cache/pip/wheels/4c/82/ad/f04abc617222b10438b1285ab9b5cfaecd180c10a7c81cff54
# Successfully built pydataset
# ...

# %%
from pydataset import data
tg = data("ToothGrowth")
tg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 1 to 60
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   len     60 non-null     float64
#  1   supp    60 non-null     object
#  2   dose    60 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.9+ KB

# %%
tg.head()
# Out:
#     len supp  dose
# 1   4.2   VC   0.5
# 2  11.5   VC   0.5
# 3   7.3   VC   0.5
# 4   5.8   VC   0.5
# 5   6.4   VC   0.5

# %%
tg.tail()
# Out:
#      len supp  dose
# 56  30.9   OJ   2.0
# 57  26.4   OJ   2.0
# 58  27.3   OJ   2.0
# 59  29.4   OJ   2.0
# 60  23.0   OJ   2.0

# %%
tg.supp.value_counts()
# Out:
# supp
# VC    30
# OJ    30
# Name: count, dtype: int64

# %%
tg.dose.value_counts()
# Out:
# dose
# 0.5    20
# 1.0    20
# 2.0    20
# Name: count, dtype: int64

# %%
tg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 1 to 60
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   len     60 non-null     float64
#  1   supp    60 non-null     object
#  2   dose    60 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.9+ KB

# %%
tg.describe()
# Out:
#              len       dose
# count  60.000000  60.000000
# mean   18.813333   1.166667
# std     7.649315   0.628872
# min     4.200000   0.500000
# 25%    13.075000   0.500000
# 50%    19.250000   1.000000
# 75%    25.275000   2.000000
# max    33.900000   2.000000

# %%
import seaborn as sns
sns.boxplot(data=tg, x="dose", y="len", hue="supp")
plt.title("기니피그 치아 성장")
plt.xlabel("치아길이(mm)")
plt.ylabel("용량(mg/day)")
plt.legend(title="suppliment")
plt.tight_layout
plt.show()

# %%
import seaborn as sns
sns.stripplot(data=tg, x="dose", y="len", hue="supp")
plt.title("기니피그 치아 성장")
plt.xlabel("치아길이(mm)")
plt.ylabel("용량(mg/day)")
plt.legend(title="suppliment")
plt.tight_layout
plt.show()

# %%
import seaborn as sns
sns.stripplot(data=tg, x="dose", y="len", hue="supp", dodge="True")
plt.title("기니피그 치아 성장")
plt.xlabel("치아길이(mm)")
plt.ylabel("용량(mg/day)")
plt.legend(title="suppliment")
plt.tight_layout
plt.show()

# %%
import seaborn as sns
sns.boxplot(data=tg, x="dose", y="len", hue="supp", dodge="True")
plt.title("기니피그 치아 성장")
plt.xlabel("치아길이(mm)")
plt.ylabel("용량(mg/day)")
plt.legend(title="suppliment")
plt.tight_layout()
plt.show()

# %%
plt.plot([1, 2, 3, 4], [5, 6, 7, 8], ls='', marker=',', color='red')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [5, 6, 7, 8], ls=':', marker=',', color='red')
plt.show()

# %%
mtc = data('mtcars')
mtc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, Mazda RX4 to Volvo 142E
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     32 non-null     float64
#  1   cyl     32 non-null     int64
#  2   disp    32 non-null     float64
#  3   hp      32 non-null     int64
#  4   drat    32 non-null     float64
#  5   wt      32 non-null     float64
#  6   qsec    32 non-null     float64
#  7   vs      32 non-null     int64
#  8   am      32 non-null     int64
#  9   gear    32 non-null     int64
#  10  carb    32 non-null     int64
# dtypes: float64(5), int64(6)
# memory usage: 3.0+ KB

# %%
mtc.head()
# Out:
#                     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4          21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag      21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710         22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive     21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#                    carb
# Mazda RX4             4
# Mazda RX4 Wag         4
# Datsun 710            1
# Hornet 4 Drive        1
# Hornet Sportabout     2

# %%
import seaborn as sns

ax = sns.countplot(mtc, x='gear', order=mtc.gear.value_counts().index)

for p in ax.patches:
  height = p.get_height()
  ax.text(x = (p.get_x() + p.get_width() / 2.) , y = (height + .2), s = int(height), ha = 'center', size=12, color = 'blue')

ax.set_ylim(0, 17)
plt.show()

# %%
lcs = data("LifeCycleSavings")
lcs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, Australia to Malaysia
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sr      50 non-null     float64
#  1   pop15   50 non-null     float64
#  2   pop75   50 non-null     float64
#  3   dpi     50 non-null     float64
#  4   ddpi    50 non-null     float64
# dtypes: float64(5)
# memory usage: 2.3+ KB

# %%
df = lcs[:5][['pop15']]

# %%
df
# Out:
#            pop15
# Australia  29.35
# Austria    23.32
# Belgium    23.80
# Bolivia    41.89
# Brazil     42.19

# %%
plt.bar(df.index, df.pop15)
plt.title("국가별 15세 미만 연구비율")
plt.xlabel("국가")
plt.ylabel("15세미만 인구비율(%)")
# Out:
# Text(0, 0.5, '15세미만 인구비율(%)')

# %%
plt.hist(mtc.mpg)
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtc.mpg, rwidth=.7 ,edgecolor='yellow')
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtc.wt, edgecolor='white')
# Out:
# (array([3., 3., 3., 3., 9., 7., 1., 0., 0., 3.]),
#  array([1.513 , 1.9041, 2.2952, 2.6863, 3.0774, 3.4685, 3.8596, 4.2507,
#         4.6418, 5.0329, 5.424 ]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
plt.hist(mtc.wt, bins = np.arange(1, 6.5, .5), edgecolor='white')
# Out:
# (array([0., 4., 4., 4., 9., 7., 1., 0., 3., 0.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
plt.hist(mtc.wt, bins = (1.5, 2.5, 4.5, 5.5) , edgecolor='white')
# Out:
# (array([ 8., 21.,  3.]),
#  array([1.5, 2.5, 4.5, 5.5]),
#  <BarContainer object of 3 artists>)

# %%
import numpy as np
plt.hist(mtc.wt, bins = (1.5, 2.5, 4.5, 5.5) , edgecolor='white', density=True)
# Out:
# (array([0.25    , 0.328125, 0.09375 ]),
#  array([1.5, 2.5, 4.5, 5.5]),
#  <BarContainer object of 3 artists>)

# %%
from pydataset import data
iris = data('iris')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB

# %%
iris.Species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.Species.value_counts()
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
plt.hist(iris['Sepal.Length'], bins=20, color='red', alpha=.5, edgecolor='white' )
# Out:
# (array([ 4.,  5.,  7., 16.,  9.,  5., 13., 14., 10.,  6., 10., 16.,  7.,
#         11.,  4.,  2.,  4.,  1.,  5.,  1.]),
#  array([4.3 , 4.48, 4.66, 4.84, 5.02, 5.2 , 5.38, 5.56, 5.74, 5.92, 6.1 ,
#         6.28, 6.46, 6.64, 6.82, 7.  , 7.18, 7.36, 7.54, 7.72, 7.9 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(iris['Sepal.Length'], bins=20, color='red', alpha=.5, edgecolor='white' )
plt.show()

# %%
tches = plt.hist(iris['Sepal.Length'], bins=20, color='red', alpha=.5, edgecolor='white' )

# %% [markdown]
# 코드 많이 놓쳤다 나중에 보고 적어 여기야

# %%
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1919/1249512285.py in <cell line: 0>()
# ----> 1 n
#
# NameError: name 'n' is not defined

# %%
bins
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1919/2402117036.py in <cell line: 0>()
# ----> 1 bins
#
# NameError: name 'bins' is not defined

# %%
patches
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1919/2771909082.py in <cell line: 0>()
# ----> 1 patches
#
# NameError: name 'patches' is not defined

# %%
for i in range(len(patches)):
  patches[i].set_facecolor(plt.cm.viridis(n[i]/ max(n)))
  # ????
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1919/3613132776.py in <cell line: 0>()
# ----> 1 for i in range(len(patches)):
#       2   patches[i].set_facecolor(plt.cm.viridis(n[i]/ max(n)))
#       3   # ????
#
# NameError: name 'patches' is not defined
